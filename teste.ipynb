# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import pandas

# %%
df = sm.datasets.get_rdataset("Guerry", "HistData").data
df = df[['Lottery', 'Literacy', 'Wealth', 'Region']].dropna()
df.head()
# Out:
#    Lottery  Literacy  Wealth Region
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E

# %%
from patsy import dmatrices, EvalEnvironment

# %%
eval_env = EvalEnvironment.capture(0)
#eval_env.namespace["offset"] = offset
print(eval_env.namespace)
# Out:
# VarLookupDict([{}, {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import statsmodels.api as sm\nimport statsmodels.formula.api as smf\nimport numpy as np\nimport pandas', 'df = sm.datasets.get_rdataset("Guerry", "HistData").data\ndf = df[[\'Lottery\', \'Literacy\', \'Wealth\', \'Region\']].dropna()\ndf.head()', "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", "mod = smf.ols(formula='. ~ Literacy + Wealth + Region', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - Region', data=df)\nres = mod.fit()", 'res', 'res.summary', 'res.summary()', 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth:Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth * Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth + Region)^2', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth/Region)', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region ', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy | Wealth + Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + I(Wealth^2) + Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - 1', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + offset(Wealth) + Region - 1', data=df)\nres = mod.fit()", 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', 'import patsy', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'offset = df["Literacy"]', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 0})', 'def offset(term):\n    return term', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'from patsy import dmatrices, EvalEnvironment', 'def offset(term):\n    return term', 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": eval_env})', 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', 'def offset(term):\n    return term + 2', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env.namespace)'], '_oh': {2:    Lottery  Literacy  Wealth Region
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E, 6: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000012878BE1460>, 7: <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x0000012878C08A40>>, 8: <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, 42: (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), 44: (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                39      73
#           1                53      22
#           1                15      61
#           1                48      76
#           1                71      83
#           1                29      84
#           1                69      33
#           1                20      72
#           1                61      14
#           1                36      17
#           1                33      50
#           1                40       2
#           1                54      10
#           1                33      59
#           1                38      86
#           1                41      18
#           1                15      63
#           1                14      74
#           1                62      16
#           1                18      70
#           1                25      78
#           1                20      60
#           1                75      31
#           1                44      66
#           1                53      20
#           1                56      11
#           1                17      36
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj)))}, '_dh': [WindowsPath('g:/Meu Drive/Projetos/IC/pyreglin')], 'In': ['', 'import statsmodels.api as sm\nimport statsmodels.formula.api as smf\nimport numpy as np\nimport pandas', 'df = sm.datasets.get_rdataset("Guerry", "HistData").data\ndf = df[[\'Lottery\', \'Literacy\', \'Wealth\', \'Region\']].dropna()\ndf.head()', "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", "mod = smf.ols(formula='. ~ Literacy + Wealth + Region', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - Region', data=df)\nres = mod.fit()", 'res', 'res.summary', 'res.summary()', 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth:Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth * Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth + Region)^2', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth/Region)', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region ', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy | Wealth + Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + I(Wealth^2) + Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - 1', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + offset(Wealth) + Region - 1', data=df)\nres = mod.fit()", 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', 'import patsy', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'offset = df["Literacy"]', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 0})', 'def offset(term):\n    return term', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'from patsy import dmatrices, EvalEnvironment', 'def offset(term):\n    return term', 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": eval_env})', 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', 'def offset(term):\n    return term + 2', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env.namespace)'], 'Out': {2:    Lottery  Literacy  Wealth Region
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E, 6: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000012878BE1460>, 7: <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x0000012878C08A40>>, 8: <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, 42: (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), 44: (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                39      73
#           1                53      22
#           1                15      61
#           1                48      76
#           1                71      83
#           1                29      84
#           1                69      33
#           1                20      72
#           1                61      14
#           1                36      17
#           1                33      50
#           1                40       2
#           1                54      10
#           1                33      59
#           1                38      86
#           1                41      18
#           1                15      63
#           1                14      74
#           1                62      16
#           1                18      70
#           1                25      78
#           1                20      60
#           1                75      31
#           1                44      66
#           1                53      20
#           1                56      11
#           1                17      36
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj)))}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x00000128565FD760>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000128565FCBC0>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x00000128565FCBC0>, 'open': <function open at 0x0000012855AD0B80>, '_': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                39      73
#           1                53      22
#           1                15      61
#           1                48      76
#           1                71      83
#           1                29      84
#           1                69      33
#           1                20      72
#           1                61      14
#           1                36      17
#           1                33      50
#           1                40       2
#           1                54      10
#           1                33      59
#           1                38      86
#           1                41      18
#           1                15      63
#           1                14      74
#           1                62      16
#           1                18      70
#           1                25      78
#           1                20      60
#           1                75      31
#           1                44      66
#           1                53      20
#           1                56      11
#           1                17      36
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '__': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '___': <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, '__vsc_ipynb_file__': 'g:\\Meu Drive\\Projetos\\IC\\pyreglin\\teste.ipynb', '_i': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', '_ii': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', '_iii': 'def offset(term):\n    return term + 2', '_i1': 'import statsmodels.api as sm\nimport statsmodels.formula.api as smf\nimport numpy as np\nimport pandas', 'sm': <module 'statsmodels.api' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\statsmodels\\api.py'>, 'smf': <module 'statsmodels.formula.api' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\statsmodels\\formula\\api.py'>, 'np': <module 'numpy' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\numpy\\__init__.py'>, 'pandas': <module 'pandas' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>, '_i2': 'df = sm.datasets.get_rdataset("Guerry", "HistData").data\ndf = df[[\'Lottery\', \'Literacy\', \'Wealth\', \'Region\']].dropna()\ndf.head()', 'df':     Lottery  Literacy  Wealth Region
# 0        41        37      73      E
# 1        38        51      22      N
# 2        66        13      61      C
# 3        80        46      76      E
# 4        79        69      83      E
# ..      ...       ...     ...    ...
# 80       68        28      56      W
# 81       40        25      68      W
# 82       55        13      67      C
# 83       14        62      82      E
# 84       51        47      30      C
#
# [85 rows x 4 columns], '_2':    Lottery  Literacy  Wealth Region
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E, '_i3': "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", '_i4': "mod = smf.ols(formula='. ~ Literacy + Wealth + Region', data=df)\nres = mod.fit()", '_i5': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - Region', data=df)\nres = mod.fit()", 'mod': <statsmodels.regression.linear_model.OLS object at 0x000001287DC7F770>, 'res': <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001287A614C20>, '_i6': 'res', '_6': <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000012878BE1460>, '_i7': 'res.summary', '_7': <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x0000012878C08A40>>, '_i8': 'res.summary()', '_8': <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, '_i9': 'print(res.summary())', '_i10': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth:Region', data=df)\nres = mod.fit()", '_i11': 'print(res.summary())', '_i12': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth * Region', data=df)\nres = mod.fit()", '_i13': 'print(res.summary())', '_i14': "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth + Region)^2', data=df)\nres = mod.fit()", '_i15': "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth/Region)', data=df)\nres = mod.fit()", '_i16': 'print(res.summary())', '_i17': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region ', data=df)\nres = mod.fit()", '_i18': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region', data=df)\nres = mod.fit()", '_i19': "mod = smf.ols(formula='Lottery ~ Literacy | Wealth + Region', data=df)\nres = mod.fit()", '_i20': 'print(res.summary())', '_i21': "mod = smf.ols(formula='Lottery ~ Literacy + I(Wealth^2) + Region', data=df)\nres = mod.fit()", '_i22': 'print(res.summary())', '_i23': "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", '_i24': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - 1', data=df)\nres = mod.fit()", '_i25': 'print(res.summary())', '_i26': "mod = smf.ols(formula='Lottery ~ Literacy + offset(Wealth) + Region - 1', data=df)\nres = mod.fit()", '_i27': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', '_i28': 'import patsy', 'patsy': <module 'patsy' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\patsy\\__init__.py'>, '_i29': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', '_i30': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i31': 'offset = df["Literacy"]', 'offset': <function offset at 0x000001287A9054E0>, '_i32': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i33': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i34': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', '_i35': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 0})', '_i36': 'def offset(term):\n    return term', '_i37': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i38': 'from patsy import dmatrices, EvalEnvironment', 'dmatrices': <function dmatrices at 0x00000128784C4360>, 'EvalEnvironment': <class 'patsy.eval.EvalEnvironment'>, '_i39': 'def offset(term):\n    return term', '_i40': 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": eval_env})', 'eval_env': <patsy.eval.EvalEnvironment object at 0x000001287DD0B020>, '_i41': 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', '_i42': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', '_42': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '_i43': 'def offset(term):\n    return term + 2', '_i44': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', '_44': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                39      73
#           1                53      22
#           1                15      61
#           1                48      76
#           1                71      83
#           1                29      84
#           1                69      33
#           1                20      72
#           1                61      14
#           1                36      17
#           1                33      50
#           1                40       2
#           1                54      10
#           1                33      59
#           1                38      86
#           1                41      18
#           1                15      63
#           1                14      74
#           1                62      16
#           1                18      70
#           1                25      78
#           1                20      60
#           1                75      31
#           1                44      66
#           1                53      20
#           1                56      11
#           1                17      36
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '_i45': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', '_i46': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env.namespace)'}, {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'import statsmodels.api as sm\nimport statsmodels.formula.api as smf\nimport numpy as np\nimport pandas', 'df = sm.datasets.get_rdataset("Guerry", "HistData").data\ndf = df[[\'Lottery\', \'Literacy\', \'Wealth\', \'Region\']].dropna()\ndf.head()', "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", "mod = smf.ols(formula='. ~ Literacy + Wealth + Region', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - Region', data=df)\nres = mod.fit()", 'res', 'res.summary', 'res.summary()', 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth:Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth * Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth + Region)^2', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth/Region)', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region ', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy | Wealth + Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + I(Wealth^2) + Region', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - 1', data=df)\nres = mod.fit()", 'print(res.summary())', "mod = smf.ols(formula='Lottery ~ Literacy + offset(Wealth) + Region - 1', data=df)\nres = mod.fit()", 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', 'import patsy', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'offset = df["Literacy"]', 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 0})', 'def offset(term):\n    return term', 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', 'from patsy import dmatrices, EvalEnvironment', 'def offset(term):\n    return term', 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": eval_env})', 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', 'def offset(term):\n    return term + 2', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env.namespace)'], '_oh': {2:    Lottery  Liter ...
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E, 6: <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000012878BE1460>, 7: <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x0000012878C08A40>>, 8: <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, 42: (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), 44: (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                39      73
#           1                53      22
#           1                15      61
#           1                48      76
#           1                71      83
#           1                29      84
#           1                69      33
#           1                20      72
#           1                61      14
#           1                36      17
#           1                33      50
#           1                40       2
#           1                54      10
#           1                33      59
#           1                38      86
#           1                41      18
#           1                15      63
#           1                14      74
#           1                62      16
#           1                18      70
#           1                25      78
#           1                20      60
#           1                75      31
#           1                44      66
#           1                53      20
#           1                56      11
#           1                17      36
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
# ...
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '__': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '___': <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, '__vsc_ipynb_file__': 'g:\\Meu Drive\\Projetos\\IC\\pyreglin\\teste.ipynb', '_i': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', '_ii': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', '_iii': 'def offset(term):\n    return term + 2', '_i1': 'import statsmodels.api as sm\nimport statsmodels.formula.api as smf\nimport numpy as np\nimport pandas', 'sm': <module 'statsmodels.api' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\statsmodels\\api.py'>, 'smf': <module 'statsmodels.formula.api' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\statsmodels\\formula\\api.py'>, 'np': <module 'numpy' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\numpy\\__init__.py'>, 'pandas': <module 'pandas' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\pandas\\__init__.py'>, '_i2': 'df = sm.datasets.get_rdataset("Guerry", "HistData").data\ndf = df[[\'Lottery\', \'Literacy\', \'Wealth\', \'Region\']].dropna()\ndf.head()', 'df':     Lottery  Literacy  Wealth Region
# 0        41        37      73      E
# 1        38        51      22      N
# 2        66        13      61      C
# 3        80        46      76      E
# 4        79        69      83      E
# ..      ...       ...     ...    ...
# 80       68        28      56      W
# 81       40        25      68      W
# 82       55        13      67      C
# 83       14        62      82      E
# 84       51        47      30      C
#
# [85 rows x 4 columns], '_2':    Lottery  Literacy  Wealth Region
# 0       41        37      73      E
# 1       38        51      22      N
# 2       66        13      61      C
# 3       80        46      76      E
# 4       79        69      83      E, '_i3': "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", '_i4': "mod = smf.ols(formula='. ~ Literacy + Wealth + Region', data=df)\nres = mod.fit()", '_i5': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - Region', data=df)\nres = mod.fit()", 'mod': <statsmodels.regression.linear_model.OLS object at 0x000001287DC7F770>, 'res': <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x000001287A614C20>, '_i6': 'res', '_6': <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000012878BE1460>, '_i7': 'res.summary', '_7': <bound method RegressionResults.summary of <statsmodels.regression.linear_model.OLSResults object at 0x0000012878C08A40>>, '_i8': 'res.summary()', '_8': <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                Lottery   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.292
# Method:                 Least Squares   F-statistic:                     18.32
# Date:                Fri, 15 Nov 2024   Prob (F-statistic):           2.66e-07
# Time:                        15:28:35   Log-Likelihood:                -377.13
# No. Observations:                  85   AIC:                             760.3
# Df Residuals:                      82   BIC:                             767.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     39.7979      7.873      5.055      0.000      24.135      55.460
# Literacy      -0.3780      0.136     -2.790      0.007      -0.648      -0.108
# Wealth         0.4138      0.094      4.398      0.000       0.227       0.601
# ==============================================================================
# Omnibus:                        4.586   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.101   Jarque-Bera (JB):                3.294
# Skew:                          -0.335   Prob(JB):                        0.193
# Kurtosis:                       2.307   Cond. No.                         215.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """, '_i9': 'print(res.summary())', '_i10': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth:Region', data=df)\nres = mod.fit()", '_i11': 'print(res.summary())', '_i12': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth * Region', data=df)\nres = mod.fit()", '_i13': 'print(res.summary())', '_i14': "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth + Region)^2', data=df)\nres = mod.fit()", '_i15': "mod = smf.ols(formula='Lottery ~ Literacy + (Wealth/Region)', data=df)\nres = mod.fit()", '_i16': 'print(res.summary())', '_i17': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region ', data=df)\nres = mod.fit()", '_i18': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth | Region', data=df)\nres = mod.fit()", '_i19': "mod = smf.ols(formula='Lottery ~ Literacy | Wealth + Region', data=df)\nres = mod.fit()", '_i20': 'print(res.summary())', '_i21': "mod = smf.ols(formula='Lottery ~ Literacy + I(Wealth^2) + Region', data=df)\nres = mod.fit()", '_i22': 'print(res.summary())', '_i23': "mod = smf.ols(formula='Lottery ~ .', data=df)\nres = mod.fit()", '_i24': "mod = smf.ols(formula='Lottery ~ Literacy + Wealth + Region - 1', data=df)\nres = mod.fit()", '_i25': 'print(res.summary())', '_i26': "mod = smf.ols(formula='Lottery ~ Literacy + offset(Wealth) + Region - 1', data=df)\nres = mod.fit()", '_i27': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', '_i28': 'import patsy', 'patsy': <module 'patsy' from 'c:\\Users\\Salvador Netto\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\patsy\\__init__.py'>, '_i29': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": \'Literacy\'})', '_i30': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i31': 'offset = df["Literacy"]', 'offset': <function offset at 0x000001287A9054E0>, '_i32': 'patsy.dmatrices(\'Lottery + offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i33': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i34': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', '_i35': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 0})', '_i36': 'def offset(term):\n    return term', '_i37': 'patsy.dmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": offset})', '_i38': 'from patsy import dmatrices, EvalEnvironment', 'dmatrices': <function dmatrices at 0x00000128784C4360>, 'EvalEnvironment': <class 'patsy.eval.EvalEnvironment'>, '_i39': 'def offset(term):\n    return term', '_i40': 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": eval_env})', 'eval_env': <patsy.eval.EvalEnvironment object at 0x000001287DD0B020>, '_i41': 'eval_env = EvalEnvironment.capture(0)\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env={"offset": 1})', '_i42': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', '_42': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                37      73
#           1                51      22
#           1                13      61
#           1                46      76
#           1                69      83
#           1                27      84
#           1                67      33
#           1                18      72
#           1                59      14
#           1                34      17
#           1                31      50
#           1                38       2
#           1                52      10
#           1                31      59
#           1                36      86
#           1                39      18
#           1                13      63
#           1                12      74
#           1                60      16
#           1                16      70
#           1                23      78
#           1                18      60
#           1                73      31
#           1                42      66
#           1                51      20
#           1                54      11
#           1                15      36
#           1                40      26
#           1                31      23
#           1                38      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '_i43': 'def offset(term):\n    return term + 2', '_i44': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\ndmatrices(\'Lottery ~ offset(Literacy) + Wealth\', df, eval_env=eval_env)', '_44': (DesignMatrix with shape (85, 1)
#   Lottery
#        41
#        38
#        66
#        80
#        79
#        70
#        31
#        75
#        28
#        50
#        81
#         3
#        13
#        82
#        60
#        35
#        44
#        84
#        33
#        72
#        85
#        77
#        18
#        54
#        47
#        48
#        36
#        20
#        25
#        74
#   [55 rows omitted]
#   Terms:
#     'Lottery' (column 0)
#   (to view full data, use np.asarray(this_obj)), DesignMatrix with shape (85, 3)
#   Intercept  offset(Literacy)  Wealth
#           1                39      73
#           1                53      22
#           1                15      61
#           1                48      76
#           1                71      83
#           1                29      84
#           1                69      33
#           1                20      72
#           1                61      14
#           1                36      17
#           1                33      50
#           1                40       2
#           1                54      10
#           1                33      59
#           1                38      86
#           1                41      18
#           1                15      63
#           1                14      74
#           1                62      16
#           1                18      70
#           1                25      78
#           1                20      60
#           1                75      31
#           1                44      66
#           1                53      20
#           1                56      11
#           1                17      36
#           1                42      26
#           1                33      23
#           1                40      40
#   [55 rows omitted]
#   Terms:
#     'Intercept' (column 0)
#     'offset(Literacy)' (column 1)
#     'Wealth' (column 2)
#   (to view full data, use np.asarray(this_obj))), '_i45': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env)', '_i46': 'eval_env = EvalEnvironment.capture(0)\n#eval_env.namespace["offset"] = offset\nprint(eval_env.namespace)'}])

# %%
dmatrices('Lottery ~ offset(Literacy) + Wealth', df, eval_env=eval_env)
# Out:
# (DesignMatrix with shape (85, 1)
#    Lottery
#         41
#         38
#         66
#         80
#         79
#         70
#         31
#         75
#         28
#         50
#         81
#          3
#         13
#         82
#         60
#         35
#         44
#         84
#         33
#         72
#         85
#         77
#         18
#         54
#         47
#         48
#         36
#         20
#         25
#         74
#    [55 rows omitted]
#    Terms:
#      'Lottery' (column 0)
#    (to view full data, use np.asarray(this_obj)),
#  DesignMatrix with shape (85, 3)
#    Intercept  offset(Literacy)  Wealth
#            1                39      73
#            1                53      22
#            1                15      61
#            1                48      76
#            1                71      83
#            1                29      84
#            1                69      33
#            1                20      72
#            1                61      14
#            1                36      17
#            1                33      50
#            1                40       2
#            1                54      10
#            1                33      59
#            1                38      86
#            1                41      18
#            1                15      63
#            1                14      74
#            1                62      16
#            1                18      70
#            1                25      78
#            1                20      60
#            1                75      31
#            1                44      66
#            1                53      20
#            1                56      11
#            1                17      36
#            1                42      26
#            1                33      23
#            1                40      40
#    [55 rows omitted]
#    Terms:
#      'Intercept' (column 0)
#      'offset(Literacy)' (column 1)
#      'Wealth' (column 2)
#    (to view full data, use np.asarray(this_obj)))
